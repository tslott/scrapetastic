# %%
import requests
import pandas as pd

from bs4 import BeautifulSoup

# %%
df = pd.read_pickle('./data/tryg_donations.pickle')

# %%
df['Id'].nunique()
# Out:
# 4923

# %%
df
# Out:
#      TargetAreaClass      Id  \
# 0             health  129902
# 1             health  129548
# 2            welfare  130138
# 3             health  129405
# 4             health  129600
# ...              ...     ...
# 4923          health  102173
# 4924          health  102174
# 4925          health  102175
# 4926          health  102176
# 4927          safety  122150
#
#                                             Institution  \
# 0                                        Rigshospitalet
# 1     SDU / Rygcenter Syddanmark, Middelfart Sygehus...
# 2                                    Aarhus Universitet
# 3                                        Rigshospitalet
# 4     Forskningsenheden ved Børne & Ungdompsykiatris...
# ...                                                 ...
# 4923                                 Aarhus Universitet
# 4924                                Bispebjerg Hospital
# 4925                             Københavns Universitet
# ...

# %%
df.to_csv('tryg_donationer.csv', index=False)
